# %% [markdown]
#  - http://pandas.pydata.org/
#  - http://matplotlib.org/
#  - http://scikits.appspot.com/scikits
#  - "C:\Users\cl\.ipython\profile_default\ipython_config.py"
#   - https://plot.ly/

# %%
import pandas as pd #import pandas, used for data manipulation
import os #for manipulating python
import matplotlib as mpl

# %%
from matplotlib import pyplot

# %%
# mpl.style.available

# %%
# mpl.style.use('ggplot')

# %%
os.listdir('.')
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  '2017-12-08.ipynb',
#  'README.md',
#  'top_housing.csv']

# %% [markdown]
# dfjghsnilergbt

# %% [markdown]
# # heading

# %% [markdown]
# ## heading

# %%
a = 'test'
a
# Out:
# 'test'

# %%
'the variable i just added was {} again, I said it was {}'.format(a,a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-6d25e3c1aa2b> in <module>()
# ----> 1 'the variable i just added was {} again, I said it was {}'.format(a,a)
#
# NameError: name 'a' is not defined

# %%
data_loc = r"C:\Users\cl\code\chrisandparth\top_housing.csv"

# %%
pd.read_csv?

# %%
df = pd.read_csv(data_loc)

# %%
pd.read_csv?

# %%
df
# Out:
#     TOP HOUSING
# 0          3.28
# 1          3.26
# 2          3.29
# 3          3.30
# 4          3.27
# 5          3.25
# 6          3.31
# 7          3.28
# 8          3.28
# 9          3.29
# 10         3.27
# 11         3.28
# 12         3.25
# 13         3.26
# 14         3.31
# 15         3.30
# 16         3.27
# 17         3.32
# 18         3.27
# 19         3.26
# 20         3.25
# 21         3.24
# 22         3.24
# 23         3.26
# 24         3.24
# 25         3.25
# 26         3.28
# 27         3.27
# 28         3.30
# 29         3.24
# 30         3.28
# 31         3.30
# 32         3.21
# 33         3.25
# 34         3.25
# 35         3.23
# 36         3.24
# 37         3.23

# %%
df.

# %%
a = df.hist?

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002AEF3B2BA58>]], dtype=object)

# %%
df.std()
# Out:
# TOP HOUSING    0.025752
# dtype: float64

# %%
df.mean()
# Out:
# TOP HOUSING    3.267368
# dtype: float64

# %%
df.median()
# Out:
# TOP HOUSING    3.27
# dtype: float64

# %%
df.columns = ['top_housing']
df.head(3)
# Out:
#    top_housing
# 0         3.28
# 1         3.26
# 2         3.29

# %%
df.top_housing
# Out:
# 0     3.28
# 1     3.26
# 2     3.29
# 3     3.30
# 4     3.27
# 5     3.25
# 6     3.31
# 7     3.28
# 8     3.28
# 9     3.29
# 10    3.27
# 11    3.28
# 12    3.25
# 13    3.26
# 14    3.31
# 15    3.30
# 16    3.27
# 17    3.32
# 18    3.27
# 19    3.26
# 20    3.25
# 21    3.24
# 22    3.24
# 23    3.26
# 24    3.24
# 25    3.25
# 26    3.28
# 27    3.27
# 28    3.30
# 29    3.24
# 30    3.28
# 31    3.30
# 32    3.21
# 33    3.25
# 34    3.25
# 35    3.23
# 36    3.24
# 37    3.23
# Name: top_housing, dtype: float64

# %%
df.iloc[0]
# Out:
# top_housing    3.28
# Name: 0, dtype: float64

# %%
df.loc[5]
# Out:
# top_housing    3.25
# Name: 5, dtype: float64

# %%
len(df)
# Out:
# 38

# %%
df<3.24
# Out:
#     top_housing
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
# 30        False
# 31        False
# 32         True
# 33        False
# 34        False
# 35         True
# 36        False
# 37         True

# %%
df[df.top_housing<3.24]
# Out:
#     top_housing
# 32         3.21
# 35         3.23
# 37         3.23

# %%
b = df[df.top_housing<3.24]

# %%
b.count()
# Out:
# top_housing    3
# dtype: int64

# %%
a = df.top_housing > 3.23

# %%
a.count()
# Out:
# 38

# %%
std = df.top_housing.std()
mean = df.top_housing.mean()
print(std,mean)
# Out:
# 0.0257518522583685 3.2673684210526313

# %%
print("The standard deviation is {} and the mean is {} ".format(std, mean))
# Out:
# The standard deviation is 0.0257518522583685 and the mean is 3.2673684210526313

# %%
LSL = mean-3*std
USL = mean+3*std
print(USL,LSL)
# Out:
# 3.344623977827737 3.1901128642775256

# %%
df = df[df.top_housing>=LSL]
df = df[df.top_housing<=USL]

# %%
df.top_housing.values?

# %%
import cv2

# %%
cap = cv2.VideoCapture(0)

# %%
ret, img = cap.read()

# %%
img?

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,300:500,:])

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
img_rgb = cv2.cvtColor?

# %%
img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
plt.imshow(img[:,:,[2,1,0]])

# %%
plt.imshow(img[:,200:500,:])

# %%
img[100,100,:]
# Out:
# array([74, 65, 65], dtype=uint8)

# %%
def this_is_a_function(input):
    '''
    documentation
    documenation
    '''
    return input*2

# %%
this_is_a_function?

# %%
df['other_column']=df.top_housing+1
df
# Out:
#     top_housing  other_column
# 0          3.28          4.28
# 1          3.26          4.26
# 2          3.29          4.29
# 3          3.30          4.30
# 4          3.27          4.27
# 5          3.25          4.25
# 6          3.31          4.31
# 7          3.28          4.28
# 8          3.28          4.28
# 9          3.29          4.29
# 10         3.27          4.27
# 11         3.28          4.28
# 12         3.25          4.25
# 13         3.26          4.26
# 14         3.31          4.31
# 15         3.30          4.30
# 16         3.27          4.27
# 17         3.32          4.32
# 18         3.27          4.27
# 19         3.26          4.26
# 20         3.25          4.25
# 21         3.24          4.24
# 22         3.24          4.24
# 23         3.26          4.26
# 24         3.24          4.24
# 25         3.25          4.25
# 26         3.28          4.28
# 27         3.27          4.27
# 28         3.30          4.30
# 29         3.24          4.24
# ...

# %%
def thresh(row):
    if row<3.28:
        return 0
    else:
        return row+1

# %%
df['other_column'] = df['TOP HOUSING']+1

# %%
df['other_other_column'] = df['TOP HOUSING'].apply(lambda x: thresh(x))

# %%
df
# Out:
#     TOP HOUSING  other_column  other_other_column
# 0          3.28          4.28                4.28
# 1          3.26          4.26                0.00
# 2          3.29          4.29                4.29
# 3          3.30          4.30                4.30
# 4          3.27          4.27                0.00
# 5          3.25          4.25                0.00
# 6          3.31          4.31                4.31
# 7          3.28          4.28                4.28
# 8          3.28          4.28                4.28
# 9          3.29          4.29                4.29
# 10         3.27          4.27                0.00
# 11         3.28          4.28                4.28
# 12         3.25          4.25                0.00
# 13         3.26          4.26                0.00
# 14         3.31          4.31                4.31
# 15         3.30          4.30                4.30
# 16         3.27          4.27                0.00
# 17         3.32          4.32                4.32
# ...

# %%
def test_func(input):
    try:
        return input/2
    except:
        return "couldn't parse {}".format(input)
#         pass

# %%
test_func('sdfgdsfgdfgdfs')
# Out:
# "couldn't parse sdfgdsfgdfgdfs"
